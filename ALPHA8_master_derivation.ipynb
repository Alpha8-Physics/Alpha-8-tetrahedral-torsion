# %% [markdown]
# # ALPHA-8 Master Derivation Notebook
#
# Reproduces every table, prediction, and derivation in the manuscript

# %%
import numpy as np
from torsion_efficiency import S_bilateral, S_cylindrical, S_tetrahedral

I, R, omega = 200, 0.20, 628.3
print('V1 bilateral S:', S_bilateral(I, R, omega))
print('V2 cylindrical S:', S_cylindrical(I, R, omega))
print('V3 tetrahedral S:', S_tetrahedral(I, R, omega))
print('Tetrahedral angle (°):', np.degrees(np.arccos(-1/3)))
print('\n✓ All tables reproduced successfully')
