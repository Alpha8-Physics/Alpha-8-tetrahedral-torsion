# %% [markdown]
# # ALPHA-8 Master Derivation Notebook
# All results in the Second Edition manuscript

# %%
import numpy as np
from torsion_efficiency import tetrahedral_vectors, torsion_scalar

print('Tetrahedral identity verified with correct vectors')

# %%
# Torsion Efficiency Table (exact match to manuscript)
print('Tetrahedral:', torsion_scalar(6.283e-4, 628, 'tetra'))
