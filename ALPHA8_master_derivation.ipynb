# %% [markdown]
# # ALPHA-8 Master Derivation Notebook
# Reproduces all tables and predictions in the manuscript

# %%
import numpy as np
from torsion_efficiency import S_bilateral, S_cylindrical, S_tetrahedral

I, R, omega = 200, 0.20, 628.3
print('V1 bilateral:', S_bilateral(I,R,omega))
print('V2 cylindrical:', S_cylindrical(I,R,omega))
print('V3 tetrahedral:', S_tetrahedral(I,R,omega))
